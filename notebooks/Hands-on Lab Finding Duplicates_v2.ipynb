# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>

# %% [markdown]
# # **Finding Duplicates Lab**

# %% [markdown]
# Estimated time needed: **30** minutes

# %% [markdown]
# ## Introduction

# %% [markdown]
# Data wrangling is a critical step in preparing datasets for analysis, and handling duplicates plays a key role in ensuring data accuracy. In this lab, you will focus on identifying and removing duplicate entries from your dataset.

# %% [markdown]
# ## Objectives

# %% [markdown]
# In this lab, you will perform the following:

# %% [markdown]
# 1. Identify duplicate rows in the dataset and analyze their characteristics.
# 2. Visualize the distribution of duplicates based on key attributes.
# 3. Remove duplicate values strategically based on specific criteria.
# 4. Outline the process of verifying and documenting duplicate removal.

# %% [markdown]
# ## Hands on Lab

# %% [markdown]
# Install the needed library

# %%
# !pip install pandas
# !pip install matplotlib
# Out:
# Collecting pandas
#   Downloading pandas-2.2.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (89 kB)
# Collecting numpy>=1.26.0 (from pandas)
#   Downloading numpy-2.2.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (62 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.12/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.12/site-packages (from pandas) (2024.2)
# Collecting tzdata>=2022.7 (from pandas)
#   Downloading tzdata-2025.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Downloading pandas-2.2.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.7/12.7 MB 150.8 MB/s eta 0:00:00
# Downloading numpy-2.2.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.1/16.1 MB 147.1 MB/s eta 0:00:00
# Downloading tzdata-2025.2-py2.py3-none-any.whl (347 kB)
# Installing collected packages: tzdata, numpy, pandas
# Successfully installed numpy-2.2.4 pandas-2.2.3 tzdata-2025.2
# Collecting matplotlib
#   Downloading matplotlib-3.10.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Downloading contourpy-1.3.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Downloading fonttools-4.57.0-cp312-cp312-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (102 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Downloading kiwisolver-1.4.8-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.2 kB)
# Requirement already satisfied: numpy>=1.23 in /opt/conda/lib/python3.12/site-packages (from matplotlib) (2.2.4)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.12/site-packages (from matplotlib) (24.2)
# Collecting pillow>=8 (from matplotlib)
#   Downloading pillow-11.2.1-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (8.9 kB)
# Collecting pyparsing>=2.3.1 (from matplotlib)
#   Downloading pyparsing-3.2.3-py3-none-any.whl.metadata (5.0 kB)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.12/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Downloading matplotlib-3.10.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (8.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.6/8.6 MB 131.3 MB/s eta 0:00:00
# Downloading contourpy-1.3.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (323 kB)
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.57.0-cp312-cp312-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 134.2 MB/s eta 0:00:00
# Downloading kiwisolver-1.4.8-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 73.6 MB/s eta 0:00:00
# Downloading pillow-11.2.1-cp312-cp312-manylinux_2_28_x86_64.whl (4.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.6/4.6 MB 127.2 MB/s eta 0:00:00
# Downloading pyparsing-3.2.3-py3-none-any.whl (111 kB)
# Installing collected packages: pyparsing, pillow, kiwisolver, fonttools, cycler, contourpy, matplotlib
# Successfully installed contourpy-1.3.2 cycler-0.12.1 fonttools-4.57.0 kiwisolver-1.4.8 matplotlib-3.10.1 pillow-11.2.1 pyparsing-3.2.3

# %% [markdown]
# Import pandas module

# %%
import pandas as pd

# %% [markdown]
# Import matplotlib

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ## **Load the dataset into a dataframe**

# %% [markdown]
# <h2>Read Data</h2>
# <p>
# We utilize the <code>pandas.read_csv()</code> function for reading CSV files. However, in this version of the lab, which operates on JupyterLite, the dataset needs to be downloaded to the interface using the provided code below.
# </p>

# %%
# Load the dataset directly from the URL
file_path = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/VYPrOu0Vs3I0hKLLjiPGrA/survey-data-with-duplicate.csv"
df = pd.read_csv(file_path)

# Display the first few rows
print(df.head())
# Out:
#    ResponseId                      MainBranch                 Age  \
# 0           1  I am a developer by profession  Under 18 years old
# 1           2  I am a developer by profession     35-44 years old
# 2           3  I am a developer by profession     45-54 years old
# 3           4           I am learning to code     18-24 years old
# 4           5  I am a developer by profession     18-24 years old
#
#             Employment RemoteWork   Check  \
# 0  Employed, full-time     Remote  Apples
# 1  Employed, full-time     Remote  Apples
# 2  Employed, full-time     Remote  Apples
# 3   Student, full-time        NaN  Apples
# 4   Student, full-time        NaN  Apples
#
#                                     CodingActivities  \
# 0                                              Hobby
# 1  Hobby;Contribute to open-source projects;Other...
# 2  Hobby;Contribute to open-source projects;Other...
# 3                                                NaN
# 4                                                NaN
#
#                                              EdLevel  \
# 0                          Primary/elementary school
# 1       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 2    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 3  Some college/university study without earning ...
# 4  Secondary school (e.g. American high school, G...
#
#                                            LearnCode  \
# 0                             Books / Physical media
# 1  Books / Physical media;Colleague;On the job tr...
# 2  Books / Physical media;Colleague;On the job tr...
# 3  Other online resources (e.g., videos, blogs, f...
# 4  Other online resources (e.g., videos, blogs, f...
#
#                                      LearnCodeOnline  ... JobSatPoints_6  \
# 0                                                NaN  ...            NaN
# 1  Technical documentation;Blogs;Books;Written Tu...  ...            0.0
# 2  Technical documentation;Blogs;Books;Written Tu...  ...            NaN
# 3  Stack Overflow;How-to videos;Interactive tutorial  ...            NaN
# 4  Technical documentation;Blogs;Written Tutorial...  ...            NaN
#
#   JobSatPoints_7 JobSatPoints_8 JobSatPoints_9 JobSatPoints_10  \
# 0            NaN            NaN            NaN             NaN
# 1            0.0            0.0            0.0             0.0
# 2            NaN            NaN            NaN             NaN
# 3            NaN            NaN            NaN             NaN
# 4            NaN            NaN            NaN             NaN
#
#   JobSatPoints_11           SurveyLength SurveyEase ConvertedCompYearly JobSat
# 0             NaN                    NaN        NaN                 NaN    NaN
# 1             0.0                    NaN        NaN                 NaN    NaN
# 2             NaN  Appropriate in length       Easy                 NaN    NaN
# 3             NaN               Too long       Easy                 NaN    NaN
# 4             NaN              Too short       Easy                 NaN    NaN
#
# [5 rows x 114 columns]

# %% [markdown]
# Load the data into a pandas dataframe:

# %% [markdown]
# Note: If you are working on a local Jupyter environment, you can use the URL directly in the pandas.read_csv() function as shown below:

# %%
# df = pd.read_csv("https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/n01PQ9pSmiRX6520flujwQ/survey-data.csv")

# %% [markdown]
# ## Identify and Analyze Duplicates

# %% [markdown]
# ### Task 1: Identify Duplicate Rows
# 1. Count the number of duplicate rows in the dataset.
# 3. Display the first few duplicate rows to understand their structure.

# %%
## Write your code here
duplicates_count = df.duplicated().sum()
duplicates = df[df.duplicated()]

print(f"Nombre de lignes dupliquées : {duplicates_count}")
print("Premières lignes dupliquées :")
print(duplicates.head())
# Out:
# Nombre de lignes dupliquées : 20
# Premières lignes dupliquées :
#        ResponseId                      MainBranch                 Age  \
# 65437           1  I am a developer by profession  Under 18 years old
# 65438           2  I am a developer by profession     35-44 years old
# 65439           3  I am a developer by profession     45-54 years old
# 65440           4           I am learning to code     18-24 years old
# 65441           5  I am a developer by profession     18-24 years old
#
#                 Employment RemoteWork   Check  \
# 65437  Employed, full-time     Remote  Apples
# 65438  Employed, full-time     Remote  Apples
# 65439  Employed, full-time     Remote  Apples
# 65440   Student, full-time        NaN  Apples
# 65441   Student, full-time        NaN  Apples
#
#                                         CodingActivities  \
# 65437                                              Hobby
# 65438  Hobby;Contribute to open-source projects;Other...
# 65439  Hobby;Contribute to open-source projects;Other...
# 65440                                                NaN
# 65441                                                NaN
#
#                                                  EdLevel  \
# 65437                          Primary/elementary school
# 65438       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 65439    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 65440  Some college/university study without earning ...
# 65441  Secondary school (e.g. American high school, G...
#
#                                                LearnCode  \
# 65437                             Books / Physical media
# 65438  Books / Physical media;Colleague;On the job tr...
# 65439  Books / Physical media;Colleague;On the job tr...
# 65440  Other online resources (e.g., videos, blogs, f...
# 65441  Other online resources (e.g., videos, blogs, f...
#
#                                          LearnCodeOnline  ... JobSatPoints_6  \
# 65437                                                NaN  ...            NaN
# 65438  Technical documentation;Blogs;Books;Written Tu...  ...            0.0
# 65439  Technical documentation;Blogs;Books;Written Tu...  ...            NaN
# 65440  Stack Overflow;How-to videos;Interactive tutorial  ...            NaN
# 65441  Technical documentation;Blogs;Written Tutorial...  ...            NaN
#
#       JobSatPoints_7 JobSatPoints_8 JobSatPoints_9 JobSatPoints_10  \
# 65437            NaN            NaN            NaN             NaN
# 65438            0.0            0.0            0.0             0.0
# 65439            NaN            NaN            NaN             NaN
# 65440            NaN            NaN            NaN             NaN
# 65441            NaN            NaN            NaN             NaN
#
#       JobSatPoints_11           SurveyLength SurveyEase ConvertedCompYearly  \
# 65437             NaN                    NaN        NaN                 NaN
# 65438             0.0                    NaN        NaN                 NaN
# 65439             NaN  Appropriate in length       Easy                 NaN
# 65440             NaN               Too long       Easy                 NaN
# 65441             NaN              Too short       Easy                 NaN
#
#       JobSat
# 65437    NaN
# 65438    NaN
# 65439    NaN
# 65440    NaN
# 65441    NaN
#
# [5 rows x 114 columns]

# %% [markdown]
# ### Task 2: Analyze Characteristics of Duplicates
# 1. Identify duplicate rows based on selected columns such as MainBranch, Employment, and RemoteWork. Analyse which columns frequently contain identical values within these duplicate rows.
# 2. Analyse the characteristics of rows that are duplicates based on a subset of columns, such as MainBranch, Employment, and RemoteWork. Determine which columns frequently have identical values across these rows.

# %%
## Write your code here
subset_columns = ["MainBranch", "Employment", "RemoteWork"]
duplicates_subset = df[df.duplicated(subset=subset_columns, keep=False)]

duplicates_subset_count = duplicates_subset.shape[0]

print(f"Nombre de doublons basés sur {subset_columns}: {duplicates_subset_count}")
print("Premières lignes dupliquées basées sur les colonnes sélectionnées :")
print(duplicates_subset.head())

other_columns = [col for col in df.columns if col not in subset_columns]
for column in other_columns:
    print(f"\nFréquence des valeurs dans la colonne '{column}' pour les doublons :")
    print(duplicates_subset[column].value_counts())
# Out:
# Nombre de doublons basés sur ['MainBranch', 'Employment', 'RemoteWork']: 65290
# Premières lignes dupliquées basées sur les colonnes sélectionnées :
#    ResponseId                      MainBranch                 Age  \
# 0           1  I am a developer by profession  Under 18 years old
# 1           2  I am a developer by profession     35-44 years old
# 2           3  I am a developer by profession     45-54 years old
# 3           4           I am learning to code     18-24 years old
# 4           5  I am a developer by profession     18-24 years old
#
#             Employment RemoteWork   Check  \
# 0  Employed, full-time     Remote  Apples
# 1  Employed, full-time     Remote  Apples
# 2  Employed, full-time     Remote  Apples
# 3   Student, full-time        NaN  Apples
# 4   Student, full-time        NaN  Apples
#
#                                     CodingActivities  \
# 0                                              Hobby
# 1  Hobby;Contribute to open-source projects;Other...
# 2  Hobby;Contribute to open-source projects;Other...
# 3                                                NaN
# 4                                                NaN
#
#                                              EdLevel  \
# 0                          Primary/elementary school
# 1       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 2    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 3  Some college/university study without earning ...
# 4  Secondary school (e.g. American high school, G...
#
#                                            LearnCode  \
# 0                             Books / Physical media
# 1  Books / Physical media;Colleague;On the job tr...
# 2  Books / Physical media;Colleague;On the job tr...
# 3  Other online resources (e.g., videos, blogs, f...
# 4  Other online resources (e.g., videos, blogs, f...
#
#                                      LearnCodeOnline  ... JobSatPoints_6  \
# 0                                                NaN  ...            NaN
# 1  Technical documentation;Blogs;Books;Written Tu...  ...            0.0
# 2  Technical documentation;Blogs;Books;Written Tu...  ...            NaN
# 3  Stack Overflow;How-to videos;Interactive tutorial  ...            NaN
# 4  Technical documentation;Blogs;Written Tutorial...  ...            NaN
#
#   JobSatPoints_7 JobSatPoints_8 JobSatPoints_9 JobSatPoints_10  \
# 0            NaN            NaN            NaN             NaN
# 1            0.0            0.0            0.0             0.0
# 2            NaN            NaN            NaN             NaN
# 3            NaN            NaN            NaN             NaN
# 4            NaN            NaN            NaN             NaN
#
#   JobSatPoints_11           SurveyLength SurveyEase ConvertedCompYearly JobSat
# 0             NaN                    NaN        NaN                 NaN    NaN
# 1             0.0                    NaN        NaN                 NaN    NaN
# 2             NaN  Appropriate in length       Easy                 NaN    NaN
# 3             NaN               Too long       Easy                 NaN    NaN
# 4             NaN              Too short       Easy                 NaN    NaN
#
# [5 rows x 114 columns]
#
# Fréquence des valeurs dans la colonne 'ResponseId' pour les doublons :
# ResponseId
# 49767    2
# 35588    2
# 51198    2
# 22001    2
# 9938     2
#         ..
# 21812    1
# 21813    1
# 21814    1
# 21815    1
# 21800    1
# Name: count, Length: 65270, dtype: int64
#
# Fréquence des valeurs dans la colonne 'Age' pour les doublons :
# Age
# 25-34 years old       23878
# 35-44 years old       14926
# 18-24 years old       14054
# 45-54 years old        6243
# 55-64 years old        2565
# Under 18 years old     2552
# 65 years or older       754
# Prefer not to say       318
# Name: count, dtype: int64
#
# Fréquence des valeurs dans la colonne 'Check' pour les doublons :
# Check
# Apples    65290
# Name: count, dtype: int64
#
# Fréquence des valeurs dans la colonne 'CodingActivities' pour les doublons :
# CodingActivities
# Hobby                                                                                                                                                                              9987
# I don’t code outside of work                                                                                                                                                       6502
# Hobby;Professional development or self-paced learning from online courses                                                                                                          6201
# Hobby;Contribute to open-source projects                                                                                                                                           3730
# Professional development or self-paced learning from online courses                                                                                                                3117
#                                                                                                                                                                                    ...
# Hobby;Contribute to open-source projects;Other (please specify):;School or academic work;Freelance/contract work                                                                      1
# Other (please specify):;School or academic work;Professional development or self-paced learning from online courses;Freelance/contract work                                           1
# Other (please specify):;Bootstrapping a business;School or academic work                                                                                                              1
# Contribute to open-source projects;Other (please specify):;Bootstrapping a business;School or academic work;Professional development or self-paced learning from online courses       1
# Hobby;Contribute to open-source projects;Other (please specify):;Bootstrapping a business;School or academic work                                                                     1
# Name: count, Length: 117, dtype: int64
#
# Fréquence des valeurs dans la colonne 'EdLevel' pour les doublons :
# EdLevel
# Bachelor’s degree (B.A., B.S., B.Eng., etc.)                                          24910
# Master’s degree (M.A., M.S., M.Eng., MBA, etc.)                                       15537
# Some college/university study without earning a degree                                 7623
# Secondary school (e.g. American high school, German Realschule or Gymnasium, etc.)     5775
# Professional degree (JD, MD, Ph.D, Ed.D, etc.)                                         2964
# Associate degree (A.A., A.S., etc.)                                                    1786
# Primary/elementary school                                                              1140
# Something else                                                                          923
# Name: count, dtype: int64
#
# Fréquence des valeurs dans la colonne 'LearnCode' pour les doublons :
# LearnCode
# Other online resources (e.g., videos, blogs, forum, online community)                                                                                                 3666
# Books / Physical media;Other online resources (e.g., videos, blogs, forum, online community)                                                                          2487
# Other online resources (e.g., videos, blogs, forum, online community);School (i.e., University, College, etc)                                                         2356
# Books / Physical media;Other online resources (e.g., videos, blogs, forum, online community);Online Courses or Certification                                          2278
# Other online resources (e.g., videos, blogs, forum, online community);Online Courses or Certification                                                                 2174
#                                                                                                                                                                       ...
# On the job training;Coding Bootcamp;Friend or family member                                                                                                              1
# Books / Physical media;On the job training;School (i.e., University, College, etc);Online Courses or Certification;Friend or family member;Other (please specify):       1
# Books / Physical media;Coding Bootcamp;Friend or family member;Other (please specify):                                                                                   1
# Books / Physical media;Colleague;School (i.e., University, College, etc);Other (please specify):                                                                         1
# School (i.e., University, College, etc);Coding Bootcamp;Friend or family member                                                                                          1
# Name: count, Length: 417, dtype: int64
#
# Fréquence des valeurs dans la colonne 'LearnCodeOnline' pour les doublons :
# LearnCodeOnline
# Technical documentation;Blogs;Written Tutorials;Stack Overflow                                                                                                                                                                            603
# Technical documentation;Blogs;Books;Written Tutorials;Stack Overflow                                                                                                                                                                      505
# Technical documentation;Written Tutorials;Stack Overflow                                                                                                                                                                                  384
# Technical documentation;Blogs;Books;Written Tutorials;Stack Overflow;Social Media                                                                                                                                                         331
# Technical documentation;Blogs;Written Tutorials;Stack Overflow;Social Media                                                                                                                                                               313
#                                                                                                                                                                                                                                          ...
# Technical documentation;Books;Written Tutorials;Video-based Online Courses;Online challenges (e.g., daily or weekly coding challenges);Programming Games                                                                                    1
# Technical documentation;Blogs;Books;How-to videos;Interactive tutorial;Video-based Online Courses;Written-based Online Courses;Auditory material (e.g., podcasts)                                                                           1
# Written Tutorials;Stack Overflow;Social Media;How-to videos;Video-based Online Courses;Written-based Online Courses;AI;Certification videos                                                                                                 1
# Technical documentation;Books;Written Tutorials;Stack Overflow;Coding sessions (live or recorded);How-to videos;Interactive tutorial;Video-based Online Courses;Written-based Online Courses;AI;Certification videos;Programming Games      1
# Technical documentation;Blogs;Coding sessions (live or recorded);How-to videos;Video-based Online Courses;Written-based Online Courses;Online challenges (e.g., daily or weekly coding challenges)                                          1
# Name: count, Length: 10821, dtype: int64
#
# Fréquence des valeurs dans la colonne 'TechDoc' pour les doublons :
# TechDoc
# API document(s) and/or SDK document(s);User guides or README files found in the source repository;Traditional public search engine                                                                                          6935
# API document(s) and/or SDK document(s);User guides or README files found in the source repository;First-party knowledge base;Traditional public search engine                                                               5439
# API document(s) and/or SDK document(s);User guides or README files found in the source repository                                                                                                                           4248
# API document(s) and/or SDK document(s);User guides or README files found in the source repository;Traditional public search engine;AI-powered search/dev tool (free)                                                        3074
# API document(s) and/or SDK document(s);User guides or README files found in the source repository;First-party knowledge base;Traditional public search engine;AI-powered search/dev tool (free)                             2549
#                                                                                                                                                                                                                             ...
# Traditional public search engine;AI-powered search/dev tool (free);AI-powered search/dev tool (paid);Other (please specify):                                                                                                   1
# Traditional public search engine;AI-powered search/dev tool (paid);Other (please specify):                                                                                                                                     1
# AI-powered search/dev tool (free);AI-powered search/dev tool (paid);Other (please specify):                                                                                                                                    1
# API document(s) and/or SDK document(s);User guides or README files found in the source repository;First-party knowledge base;AI-powered search/dev tool (free);AI-powered search/dev tool (paid);Other (please specify):       1
# API document(s) and/or SDK document(s);First-party knowledge base;Traditional public search engine;AI-powered search/dev tool (free);AI-powered search/dev tool (paid);Other (please specify):                                 1
# Name: count, Length: 113, dtype: int64
#
# Fréquence des valeurs dans la colonne 'YearsCode' pour les doublons :
# YearsCode
# 10                    4560
# 5                     3709
# 6                     3487
# 8                     3443
# 7                     3331
# 4                     3279
# 15                    2810
# 20                    2635
# 12                    2557
# 3                     2509
# 9                     2251
# 14                    1819
# 25                    1670
# 2                     1633
# 11                    1632
# 13                    1475
# 30                    1457
# 16                    1398
# 18                    1228
# 17                    1039
# 40                     990
# 24                     869
# 22                     843
# 35                     735
# 1                      707
# 23                     633
# 26                     629
# Less than 1 year       563
# 19                     560
# 21                     522
# 28                     512
# 27                     504
# 32                     327
# 34                     291
# 42                     289
# 38                     283
# 29                     274
# 45                     254
# More than 50 years     250
# 36                     223
# 33                     219
# 37                     216
# 44                     192
# 43                     172
# 41                     147
# 31                     146
# 39                     145
# 46                      98
# 50                      75
# 47                      63
# 48                      62
# 49                      33
# Name: count, dtype: int64
#
# Fréquence des valeurs dans la colonne 'YearsCodePro' pour les doublons :
# YearsCodePro
# 2                     4160
# 3                     4091
# 5                     3522
# 10                    3251
# 4                     3209
# Less than 1 year      2843
# 6                     2841
# 1                     2632
# 8                     2548
# 7                     2517
# 12                    1776
# 15                    1635
# 20                    1547
# 9                     1492
# 11                    1313
# 13                    1127
# 14                    1082
# 25                     997
# 16                     945
# 18                     866
# 17                     815
# 30                     688
# 24                     632
# 19                     516
# 22                     492
# 23                     448
# 26                     426
# 27                     381
# 21                     380
# 28                     342
# 35                     285
# 29                     196
# 40                     194
# 32                     194
# 34                     169
# 38                     133
# 33                     132
# 36                     118
# 31                     106
# 37                     104
# 45                      57
# 42                      54
# 39                      53
# 41                      51
# More than 50 years      48
# 44                      41
# 43                      37
# 46                      21
# 50                      13
# 48                      12
# 49                      11
# 47                      10
# Name: count, dtype: int64
#
# Fréquence des valeurs dans la colonne 'DevType' pour les doublons :
# DevType
# Developer, full-stack                            18246
# Developer, back-end                               9921
# Student                                           5083
# Developer, front-end                              3342
# Developer, desktop or enterprise applications     2488
# Other (please specify):                           2439
# Developer, mobile                                 2016
# Developer, embedded applications or devices       1621
# Engineering manager                               1273
# Academic researcher                               1237
# Data engineer                                     1119
# Data scientist or machine learning specialist     1022
# DevOps specialist                                 1018
# Research & Development role                        938
# Senior Executive (C-Suite, VP, etc.)               835
# Developer, game or graphics                        702
# Cloud infrastructure engineer                      632
# System administrator                               552
# Developer, AI                                      542
# Developer, QA or test                              525
# Data or business analyst                           520
# Project manager                                    417
# Security professional                              353
# Educator                                           349
# Scientist                                          330
# Engineer, site reliability                         310
# Product manager                                    288
# Blockchain                                         232
# Developer Experience                               225
# Hardware Engineer                                  200
# Designer                                           181
# Database administrator                             170
# Developer Advocate                                 105
# Marketing or sales professional                     93
# Name: count, dtype: int64
#
# Fréquence des valeurs dans la colonne 'OrgSize' pour les doublons :
# OrgSize
# 20 to 99 employees                                    9748
# 100 to 499 employees                                  8693
# 10,000 or more employees                              5555
# 1,000 to 4,999 employees                              5350
# 2 to 9 employees                                      4829
# 10 to 19 employees                                    4075
# 500 to 999 employees                                  3181
# Just me - I am a freelancer, sole proprietor, etc.    3061
# 5,000 to 9,999 employees                              1867
# I don’t know                                          1061
# Name: count, dtype: int64
#
# Fréquence des valeurs dans la colonne 'PurchaseInfluence' pour les doublons :
# PurchaseInfluence
# I have some influence               19182
# I have little or no influence       17921
# I have a great deal of influence    10243
# Name: count, dtype: int64
#
# Fréquence des valeurs dans la colonne 'BuyNewTool' pour les doublons :
# BuyNewTool
# Start a free trial;Ask developers I know/work with;Visit developer communities like Stack Overflow                                                                            6614
# Start a free trial;Ask developers I know/work with                                                                                                                            4925
# Start a free trial;Ask developers I know/work with;Visit developer communities like Stack Overflow;Read ratings or reviews on third party sites like G2 Crowd                 3004
# Start a free trial                                                                                                                                                            2437
# Ask developers I know/work with;Visit developer communities like Stack Overflow                                                                                               2320
#                                                                                                                                                                               ...
# Ask a generative AI tool;Research companies that have emailed me                                                                                                                 1
# Visit developer communities like Stack Overflow;Read ratings or reviews on third party sites like G2 Crowd;Research companies that have emailed me;Other (please specify):       1
# Visit developer communities like Stack Overflow;Research companies that have emailed me;Other (please specify):                                                                  1
# Ask developers I know/work with;Ask a generative AI tool;Research companies that have emailed me;Other (please specify):                                                         1
# Start a free trial;Research companies that have advertised on sites I visit;Research companies that have emailed me;Other (please specify):                                      1
# Name: count, Length: 215, dtype: int64
#
# Fréquence des valeurs dans la colonne 'BuildvsBuy' pour les doublons :
# BuildvsBuy
# Is ready-to-go but also customizable for growth and targeted use cases         25941
# Is set up to be customized and needs to be engineered into a usable product     8752
# Out-of-the-box is ready to go with little need for customization                8613
# Name: count, dtype: int64
#
# Fréquence des valeurs dans la colonne 'TechEndorse' pour les doublons :
# TechEndorse
# APIs;Customization;Reputation for quality and excellence                                                                                                                           1497
# APIs;Customization;Integrated developer community;Quality support system;Reputation for quality and excellence;Frequent updates to features;Connected to an open source project    1225
# APIs;Customization;Reputation for quality and excellence;Connected to an open source project                                                                                       1206
# APIs;Customization;Quality support system;Reputation for quality and excellence                                                                                                    1141
# APIs;Customization;Reputation for quality and excellence;Frequent updates to features                                                                                              1040
#                                                                                                                                                                                    ...
# APIs;Integrated developer community;Frequent updates to features;Other:                                                                                                               1
# Quality support system;Reputation for quality and excellence;Frequent updates to features;Connected to an open source project;Other:                                                  1
# Customization;Integrated developer community;Quality support system;Frequent updates to features;Other:                                                                               1
# Customization;Integrated developer community;Quality support system;Reputation for quality and excellence;Other:                                                                      1
# APIs;Customization;Integrated developer community;Quality support system;AI tool integration;Frequent updates to features;Connected to an open source project;Other:                  1
# Name: count, Length: 386, dtype: int64
#
# Fréquence des valeurs dans la colonne 'Country' pour les doublons :
# Country
# United States of America                                11065
# Germany                                                  4946
# India                                                    4222
# United Kingdom of Great Britain and Northern Ireland     3224
# Ukraine                                                  2664
#                                                         ...
# Micronesia, Federated States of...                          1
# Nauru                                                       1
# Chad                                                        1
# Djibouti                                                    1
# Solomon Islands                                             1
# Name: count, Length: 185, dtype: int64
#
# Fréquence des valeurs dans la colonne 'Currency' pour les doublons :
# Currency
# EUR European Euro            12726
# USD\tUnited States dollar    10922
# INR\tIndian rupee             2899
# GBP\tPound sterling           2612
# CAD\tCanadian dollar          1636
#                              ...
# SZL\tSwazi lilangeni             1
# none\tCook Islands dollar        1
# AWG\tAruban florin               1
# BBD\tBarbadian dollar            1
# BMD\tBermudian dollar            1
# Name: count, Length: 142, dtype: int64
#
# Fréquence des valeurs dans la colonne 'CompTotal' pour les doublons :
# CompTotal
# 100000.0     939
# 60000.0      839
# 120000.0     792
# 80000.0      728
# 50000.0      704
#             ...
# 2070000.0      1
# 534000.0       1
# 195800.0       1
# 34240.0        1
# 98767.0        1
# Name: count, Length: 3334, dtype: int64
#
# Fréquence des valeurs dans la colonne 'LanguageHaveWorkedWith' pour les doublons :
# LanguageHaveWorkedWith
# HTML/CSS;JavaScript;TypeScript                                                  1003
# Python                                                                           831
# HTML/CSS;JavaScript;PHP;SQL                                                      503
# C#                                                                               453
# HTML/CSS;JavaScript                                                              450
#                                                                                 ...
# Assembly;Bash/Shell (all shells);C;Delphi;HTML/CSS;JavaScript;PHP;Python;SQL       1
# Bash/Shell (all shells);C;C++;Go;PHP;Python;R;SQL                                  1
# Groovy;R;SQL;TypeScript                                                            1
# C#;Go;HTML/CSS;Java;Kotlin;PowerShell;Python;SQL;VBA;Visual Basic (.Net)           1
# Groovy;Java;JavaScript;Kotlin;Objective-C;Rust;Swift;TypeScript                    1
# Name: count, Length: 23799, dtype: int64
#
# Fréquence des valeurs dans la colonne 'LanguageWantToWorkWith' pour les doublons :
# LanguageWantToWorkWith
# Python                                                                          919
# Rust                                                                            737
# HTML/CSS;JavaScript;TypeScript                                                  634
# C#                                                                              539
# Go                                                                              459
#                                                                                ...
# Bash/Shell (all shells);HTML/CSS;Java;Kotlin;Python;Ruby;Rust;SQL;TypeScript      1
# Bash/Shell (all shells);Java;Rust;Scala;SQL;TypeScript                            1
# Dart;F#;TypeScript                                                                1
# Assembly;Bash/Shell (all shells);C;C#;C++;Python;R                                1
# HTML/CSS;JavaScript;Python;Scala;Solidity;TypeScript                              1
# Name: count, Length: 22705, dtype: int64
#
# Fréquence des valeurs dans la colonne 'LanguageAdmired' pour les doublons :
# LanguageAdmired
# Python                                                                             1552
# HTML/CSS;JavaScript;TypeScript                                                     1059
# C#                                                                                  893
# Python;SQL                                                                          669
# Java                                                                                581
#                                                                                    ...
# Bash/Shell (all shells);Delphi;Go;HTML/CSS;JavaScript;PowerShell;SQL;TypeScript       1
# Crystal;Julia;R;Ruby                                                                  1
# C#;Java;JavaScript;Python;Rust                                                        1
# JavaScript;Lua;Python;TypeScript                                                      1
# Assembly;C#;C++;HTML/CSS;JavaScript;Python;SQL                                        1
# Name: count, Length: 12303, dtype: int64
#
# Fréquence des valeurs dans la colonne 'DatabaseHaveWorkedWith' pour les doublons :
# DatabaseHaveWorkedWith
# PostgreSQL                                                                             3214
# Microsoft SQL Server                                                                   2237
# MySQL                                                                                  2092
# SQLite                                                                                 1761
# PostgreSQL;SQLite                                                                      1171
#                                                                                        ...
# Cassandra;Dynamodb;Elasticsearch;H2;MySQL;Neo4J;PostgreSQL;Presto;Redis;Solr;SQLite       1
# H2;InfluxDB;MariaDB;MongoDB;MySQL;PostgreSQL;Redis                                        1
# Firebird;Microsoft Access;Microsoft SQL Server;Oracle;PostgreSQL;SQLite                   1
# BigQuery;MariaDB;Microsoft SQL Server;MySQL;Oracle;PostgreSQL                             1
# Cloud Firestore;Dynamodb;MySQL;Snowflake;SQLite                                           1
# Name: count, Length: 9029, dtype: int64
#
# Fréquence des valeurs dans la colonne 'DatabaseWantToWorkWith' pour les doublons :
# DatabaseWantToWorkWith
# PostgreSQL                                                                                                                                  3731
# PostgreSQL;SQLite                                                                                                                           1532
# SQLite                                                                                                                                      1474
# Microsoft SQL Server                                                                                                                        1430
# MySQL                                                                                                                                       1138
#                                                                                                                                             ...
# Cosmos DB;Couch DB;Dynamodb;H2;MariaDB;MongoDB;MySQL;PostgreSQL;SQLite                                                                         1
# Cosmos DB;Firebase Realtime Database;Microsoft SQL Server;MongoDB;MySQL;PostgreSQL;SQLite                                                      1
# Cassandra;Cloud Firestore;Dynamodb;Elasticsearch;Firebase Realtime Database;MariaDB;Microsoft SQL Server;MongoDB;MySQL;PostgreSQL;SQLite       1
# BigQuery;Elasticsearch;MariaDB;PostgreSQL;Snowflake;SQLite;Supabase                                                                            1
# Cassandra;Cloud Firestore;Cockroachdb;Dynamodb;Elasticsearch;Firebase Realtime Database;MongoDB;MySQL;Neo4J;PostgreSQL;Redis;Supabase          1
# Name: count, Length: 8454, dtype: int64
#
# Fréquence des valeurs dans la colonne 'DatabaseAdmired' pour les doublons :
# DatabaseAdmired
# PostgreSQL                                                         4886
# Microsoft SQL Server                                               2203
# SQLite                                                             1896
# MySQL                                                              1766
# PostgreSQL;SQLite                                                  1528
#                                                                    ...
# Elasticsearch;MongoDB;MySQL;PostgreSQL;Solr                           1
# Cloud Firestore;Dynamodb;Firebase Realtime Database                   1
# Databricks SQL;Microsoft SQL Server;MySQL;SQLite                      1
# Cosmos DB;Dynamodb;Elasticsearch;MongoDB;MySQL;PostgreSQL;Redis       1
# PostgreSQL;Redis;SQLite;TiDB                                          1
# Name: count, Length: 4041, dtype: int64
#
# Fréquence des valeurs dans la colonne 'PlatformHaveWorkedWith' pour les doublons :
# PlatformHaveWorkedWith
# Amazon Web Services (AWS)                                                                                                                                                 6596
# Microsoft Azure                                                                                                                                                           4081
# Google Cloud                                                                                                                                                              1808
# Amazon Web Services (AWS);Microsoft Azure                                                                                                                                 1521
# Amazon Web Services (AWS);Google Cloud                                                                                                                                    1217
#                                                                                                                                                                           ...
# Cloudflare;Digital Ocean;IBM Cloud Or Watson;Oracle Cloud Infrastructure (OCI)                                                                                               1
# Google Cloud;Heroku;IBM Cloud Or Watson                                                                                                                                      1
# Amazon Web Services (AWS);Cloudflare;Fly.io;Google Cloud;Microsoft Azure;Netlify;Supabase;Vercel                                                                             1
# Cloudflare;PythonAnywhere;Supabase;Vercel                                                                                                                                    1
# Amazon Web Services (AWS);Databricks;Digital Ocean;Google Cloud;Heroku;IBM Cloud Or Watson;Linode, now Akamai;Microsoft Azure;Oracle Cloud Infrastructure (OCI);VMware       1
# Name: count, Length: 5449, dtype: int64
#
# Fréquence des valeurs dans la colonne 'PlatformWantToWorkWith' pour les doublons :
# PlatformWantToWorkWith
# Amazon Web Services (AWS)                                                                                                   4856
# Microsoft Azure                                                                                                             2779
# Google Cloud                                                                                                                1378
# Amazon Web Services (AWS);Microsoft Azure                                                                                   1318
# Amazon Web Services (AWS);Google Cloud                                                                                      1108
#                                                                                                                             ...
# Amazon Web Services (AWS);Digital Ocean;Google Cloud;Microsoft Azure;Netlify;Supabase;Vercel                                   1
# Amazon Web Services (AWS);Cloudflare;Colocation;Digital Ocean;Google Cloud;Netlify;Oracle Cloud Infrastructure (OCI);OVH       1
# Alibaba Cloud;Databricks;OpenShift;OpenStack                                                                                   1
# Alibaba Cloud;Amazon Web Services (AWS);Cloudflare;Digital Ocean;Google Cloud;Managed Hosting;Supabase;Vercel                  1
# Amazon Web Services (AWS);Google Cloud;IBM Cloud Or Watson;OpenShift;OpenStack                                                 1
# Name: count, Length: 4760, dtype: int64
#
# Fréquence des valeurs dans la colonne 'PlatformAdmired' pour les doublons :
# PlatformAdmired
# Amazon Web Services (AWS)                                                                                       6234
# Microsoft Azure                                                                                                 3568
# Google Cloud                                                                                                    1692
# Amazon Web Services (AWS);Microsoft Azure                                                                        904
# Amazon Web Services (AWS);Google Cloud                                                                           798
#                                                                                                                 ...
# Amazon Web Services (AWS);Heroku;OpenShift                                                                         1
# Amazon Web Services (AWS);Firebase;Netlify;Vercel;VMware                                                           1
# Cloudflare;Google Cloud;Microsoft Azure;Netlify;Oracle Cloud Infrastructure (OCI);Vercel                           1
# Amazon Web Services (AWS);Databricks;Vercel                                                                        1
# Amazon Web Services (AWS);Digital Ocean;Firebase;Google Cloud;Heroku;Microsoft Azure;Netlify;Supabase;Vercel       1
# Name: count, Length: 2544, dtype: int64
#
# Fréquence des valeurs dans la colonne 'WebframeHaveWorkedWith' pour les doublons :
# WebframeHaveWorkedWith
# React                                                                                                               1281
# Spring Boot                                                                                                         1083
# Node.js                                                                                                              905
# Node.js;React                                                                                                        749
# Flask                                                                                                                747
#                                                                                                                     ...
# Angular;Express;Flask;jQuery;Node.js;WordPress                                                                         1
# CodeIgniter;jQuery;Laravel;Symfony;Yii 2                                                                               1
# ASP.NET;ASP.NET CORE;Astro;CodeIgniter;Django;Drupal;Gatsby;jQuery;Laravel;Next.js;Node.js;React;WordPress;Yii 2       1
# Angular;AngularJS;Laravel;React;WordPress                                                                              1
# ASP.NET;Blazor;FastAPI;Flask;jQuery;Node.js;Svelte;Vue.js                                                              1
# Name: count, Length: 12209, dtype: int64
#
# Fréquence des valeurs dans la colonne 'WebframeWantToWorkWith' pour les doublons :
# WebframeWantToWorkWith
# React                                                                      994
# Spring Boot                                                                949
# Node.js                                                                    618
# ASP.NET CORE                                                               608
# FastAPI                                                                    576
#                                                                           ...
# ASP.NET;ASP.NET CORE;Astro;FastAPI;Htmx;Node.js;Nuxt.js;Solid.js;Svelte      1
# ASP.NET CORE;Blazor;Express                                                  1
# Django;FastAPI;jQuery;React;Vue.js                                           1
# Angular;AngularJS;ASP.NET;ASP.NET CORE;jQuery;Next.js;React;WordPress        1
# ASP.NET;ASP.NET CORE;Blazor;Express;Next.js;Node.js;React;Vue.js             1
# Name: count, Length: 11623, dtype: int64
#
# Fréquence des valeurs dans la colonne 'WebframeAdmired' pour les doublons :
# WebframeAdmired
# React                                                                                    1419
# Spring Boot                                                                              1270
# ASP.NET CORE                                                                             1078
# Node.js                                                                                   981
# Node.js;React                                                                             817
#                                                                                          ...
# ASP.NET CORE;CodeIgniter;Vue.js                                                             1
# Astro;Fastify;Laravel;Next.js;Node.js;React                                                 1
# Angular;ASP.NET;ASP.NET CORE;Blazor;jQuery;Node.js;React;Spring Boot;Vue.js;WordPress       1
# Angular;Django;Flask;jQuery;Node.js;WordPress                                               1
# Fastify;Next.js;Node.js;React;Strapi                                                        1
# Name: count, Length: 5445, dtype: int64
#
# Fréquence des valeurs dans la colonne 'EmbeddedHaveWorkedWith' pour les doublons :
# EmbeddedHaveWorkedWith
# Rasberry Pi                                                                      3885
# Arduino;Rasberry Pi                                                              2063
# Arduino                                                                          1979
# Cargo                                                                            1007
# GNU GCC                                                                           839
#                                                                                  ...
# Catch2;CMake;Cargo;GNU GCC;Rasberry Pi                                              1
# Arduino;Boost.Test;Catch2;CMake;cppunit;GNU GCC;LLVM's Clang;MSVC;Rasberry Pi       1
# Arduino;CMake;cppunit;QMake;Rasberry Pi                                             1
# Cargo;GNU GCC;Meson;Rasberry Pi                                                     1
# Catch2;CMake;CUTE;Micronaut;Rasberry Pi                                             1
# Name: count, Length: 1624, dtype: int64
#
# Fréquence des valeurs dans la colonne 'EmbeddedWantToWorkWith' pour les doublons :
# EmbeddedWantToWorkWith
# Rasberry Pi                                                     3032
# Arduino;Rasberry Pi                                             2088
# Cargo                                                           1227
# Arduino                                                          836
# GNU GCC                                                          534
#                                                                 ...
# GNU GCC;LLVM's Clang;Meson;QMake;Rasberry Pi                       1
# CMake;cppunit;LLVM's Clang;MSVC                                    1
# Catch2;CMake;LLVM's Clang;MSVC;Ninja                               1
# Boost.Test;CMake;GNU GCC;LLVM's Clang;Meson;Ninja;PlatformIO       1
# Arduino;CMake;Cargo;Meson;Ninja;PlatformIO;Rasberry Pi             1
# Name: count, Length: 1465, dtype: int64
#
# Fréquence des valeurs dans la colonne 'EmbeddedAdmired' pour les doublons :
# EmbeddedAdmired
# Rasberry Pi                                                          3443
# Arduino;Rasberry Pi                                                  1397
# Cargo                                                                1355
# Arduino                                                              1210
# GNU GCC                                                               805
#                                                                      ...
# Arduino;doctest;Ninja;Rasberry Pi                                       1
# GNU GCC;LLVM's Clang;MSVC;QMake;Rasberry Pi                             1
# Arduino;doctest;Rasberry Pi                                             1
# Arduino;CMake;doctest;GNU GCC;LLVM's Clang;PlatformIO;Rasberry Pi       1
# Arduino;CMake;GNU GCC;Ninja;QMake;Rasberry Pi                           1
# Name: count, Length: 1049, dtype: int64
#
# Fréquence des valeurs dans la colonne 'MiscTechHaveWorkedWith' pour les doublons :
# MiscTechHaveWorkedWith
# .NET (5+)                                                                                                                                                                              2384
# .NET (5+) ;.NET Framework (1.0 - 4.8)                                                                                                                                                  2253
# Spring Framework                                                                                                                                                                       1412
# Flutter                                                                                                                                                                                1081
# React Native                                                                                                                                                                            987
#                                                                                                                                                                                        ...
# .NET (5+) ;.NET MAUI;Ktor;SwiftUI;Xamarin                                                                                                                                                 1
# .NET (5+) ;.NET Framework (1.0 - 4.8);CUDA;DirectX;Electron;Flutter;GTK;Hadoop;Hugging Face Transformers;MFC;OpenCL;Opencv;OpenGL;Spring Framework;TensorFlow;Torch/PyTorch;Xamarin       1
# .NET (5+) ;.NET Framework (1.0 - 4.8);.NET MAUI;DirectX;GTK;MFC;NumPy;OpenGL;Qt;Roslyn                                                                                                    1
# Electron;Keras;NumPy;Opencv;Ruff;TensorFlow;Torch/PyTorch                                                                                                                                 1
# Hugging Face Transformers;Keras;NumPy;Pandas;RabbitMQ;Ruff;Scikit-Learn;TensorFlow;Torch/PyTorch                                                                                          1
# Name: count, Length: 9261, dtype: int64
#
# Fréquence des valeurs dans la colonne 'MiscTechWantToWorkWith' pour les doublons :
# MiscTechWantToWorkWith
# .NET (5+)                                                                                                                                                           2376
# Flutter                                                                                                                                                              823
# Spring Framework                                                                                                                                                     809
# ...
# Knowledge_1
# Agree                         13442
# Strongly agree                10302
# Neither agree nor disagree     2389
# Disagree                       1810
# Strongly disagree               691
# Name: count, dtype: int64
#
# Fréquence des valeurs dans la colonne 'Knowledge_2' pour les doublons :
# Knowledge_2
# Agree                         9050
# Neither agree nor disagree    7278
# Disagree                      5955
# Strongly agree                3609
# Strongly disagree             2102
# Name: count, dtype: int64
#
# Fréquence des valeurs dans la colonne 'Knowledge_3' pour les doublons :
# Knowledge_3
# Agree                         10967
# Neither agree nor disagree     7418
# Disagree                       5518
# Strongly agree                 2724
# Strongly disagree              1440
# Name: count, dtype: int64
#
# Fréquence des valeurs dans la colonne 'Knowledge_4' pour les doublons :
# Knowledge_4
# Agree                         12498
# Neither agree nor disagree     7211
# Disagree                       4183
# Strongly agree                 3252
# Strongly disagree               856
# Name: count, dtype: int64
#
# Fréquence des valeurs dans la colonne 'Knowledge_5' pour les doublons :
# Knowledge_5
# Agree                         14601
# Neither agree nor disagree     5093
# Strongly agree                 4998
# Disagree                       2606
# Strongly disagree               553
# Name: count, dtype: int64
#
# Fréquence des valeurs dans la colonne 'Knowledge_6' pour les doublons :
# Knowledge_6
# Agree                         9924
# Neither agree nor disagree    7388
# Disagree                      5895
# Strongly agree                3666
# Strongly disagree              962
# Name: count, dtype: int64
#
# Fréquence des valeurs dans la colonne 'Knowledge_7' pour les doublons :
# Knowledge_7
# Agree                         10270
# Neither agree nor disagree     6542
# Disagree                       5411
# Strongly agree                 4444
# Strongly disagree              1083
# Name: count, dtype: int64
#
# Fréquence des valeurs dans la colonne 'Knowledge_8' pour les doublons :
# Knowledge_8
# Agree                         10744
# Neither agree nor disagree     7040
# Disagree                       5154
# Strongly agree                 3065
# Strongly disagree              1725
# Name: count, dtype: int64
#
# Fréquence des valeurs dans la colonne 'Knowledge_9' pour les doublons :
# Knowledge_9
# Agree                         6645
# Strongly disagree             6374
# Neither agree nor disagree    6149
# Disagree                      5885
# Strongly agree                2554
# Name: count, dtype: int64
#
# Fréquence des valeurs dans la colonne 'Frequency_1' pour les doublons :
# Frequency_1
# 1-2 times a week     16976
# Never                 7597
# 3-5 times a week      2718
# 6-10 times a week      569
# 10+ times a week       480
# Name: count, dtype: int64
#
# Fréquence des valeurs dans la colonne 'Frequency_2' pour les doublons :
# Frequency_2
# 1-2 times a week     12566
# 3-5 times a week      6509
# 10+ times a week      3465
# 6-10 times a week     3068
# Never                 2727
# Name: count, dtype: int64
#
# Fréquence des valeurs dans la colonne 'Frequency_3' pour les doublons :
# Frequency_3
# 1-2 times a week     14414
# Never                 8197
# 3-5 times a week      3444
# 6-10 times a week      862
# 10+ times a week       765
# Name: count, dtype: int64
#
# Fréquence des valeurs dans la colonne 'TimeSearching' pour les doublons :
# TimeSearching
# 30-60 minutes a day           10949
# 15-30 minutes a day            7796
# 60-120 minutes a day           5268
# Less than 15 minutes a day     2679
# Over 120 minutes a day         2187
# Name: count, dtype: int64
#
# Fréquence des valeurs dans la colonne 'TimeAnswering' pour les doublons :
# TimeAnswering
# 15-30 minutes a day           9334
# 30-60 minutes a day           8634
# Less than 15 minutes a day    5909
# 60-120 minutes a day          3700
# Over 120 minutes a day        1235
# Name: count, dtype: int64
#
# Fréquence des valeurs dans la colonne 'Frustration' pour les doublons :
# Frustration
# None of these                                                                                                                                                                                                                                                2358
# Amount of technical debt                                                                                                                                                                                                                                     2069
# Amount of technical debt;Reliability of tools/systems used in work                                                                                                                                                                                            831
# Amount of technical debt;Complexity of tech stack for deployment;Complexity of tech stack for build                                                                                                                                                           666
# Amount of technical debt;Tracking my work                                                                                                                                                                                                                     555
#                                                                                                                                                                                                                                                              ...
# Maintaining security of code being produced;None of these                                                                                                                                                                                                       1
# Showing my contributions;Complexity of tech stack for deployment;Patching/updating core components;Maintaining security of systems/platforms used in work                                                                                                       1
# Tracking my work;Complexity of tech stack for deployment;Patching/updating core components;Maintaining security of systems/platforms used in work;Reliability of tools/systems used in work                                                                     1
# Number of software tools in use;Tracking my work;Patching/updating core components;Maintaining security of systems/platforms used in work;Reliability of tools/systems used in work                                                                             1
# Amount of technical debt;Number of software tools in use;Showing my contributions;Complexity of tech stack for build;Maintaining security of code being produced;Patching/updating core components;Maintaining security of systems/platforms used in work       1
# Name: count, Length: 954, dtype: int64
#
# Fréquence des valeurs dans la colonne 'ProfessionalTech' pour les doublons :
# ProfessionalTech
# None of these                                                                                                                                                                                                                                                                             2829
# DevOps function;Automated testing;Observability tools;Knowledge sharing community;AI-assisted technology tool(s);Microservices;Developer portal or other central places to find tools/services;Continuous integration (CI) and (more often) continuous delivery;Innersource initiative    1064
# DevOps function;Automated testing;Observability tools;Knowledge sharing community;AI-assisted technology tool(s);Microservices;Developer portal or other central places to find tools/services;Continuous integration (CI) and (more often) continuous delivery                            706
# Automated testing;Continuous integration (CI) and (more often) continuous delivery                                                                                                                                                                                                         608
# Continuous integration (CI) and (more often) continuous delivery                                                                                                                                                                                                                           604
#                                                                                                                                                                                                                                                                                           ...
# Developer portal or other central places to find tools/services;Innersource initiative;None of these                                                                                                                                                                                         1
# Automated testing;Observability tools;Knowledge sharing community;AI-assisted technology tool(s);Microservices;Developer portal or other central places to find tools/services;Innersource initiative                                                                                        1
# DevOps function;Observability tools;AI-assisted technology tool(s);Microservices;Developer portal or other central places to find tools/services                                                                                                                                             1
# DevOps function;Automated testing;AI-assisted technology tool(s);Microservices;Developer portal or other central places to find tools/services;Innersource initiative                                                                                                                        1
# DevOps function;Automated testing;Observability tools;Developer portal or other central places to find tools/services;Innersource initiative                                                                                                                                                 1
# Name: count, Length: 514, dtype: int64
#
# Fréquence des valeurs dans la colonne 'ProfessionalCloud' pour les doublons :
# ProfessionalCloud
# Hybrid (on-prem and cloud)            13214
# Cloud only (single or multi-cloud)    11247
# On-prem                                4001
# Name: count, dtype: int64
#
# Fréquence des valeurs dans la colonne 'ProfessionalQuestion' pour les doublons :
# ProfessionalQuestion
# Traditional public search engine                                                                                  15801
# A coworker                                                                                                         5318
# AI-powered search (free)                                                                                           2248
# AI-powered search (paid)                                                                                           1945
# Slack search                                                                                                       1053
# Do search of internal share drives/storage locations for documentation (i.e., not a structured knowledge base)      937
# Internal Developer portal                                                                                           775
# Other:                                                                                                              554
# Microsoft Teams search                                                                                              144
# Name: count, dtype: int64
#
# Fréquence des valeurs dans la colonne 'Industry' pour les doublons :
# Industry
# Software Development                          11905
# Other:                                         3073
# Fintech                                        1641
# Internet, Telecomm or Information Services     1623
# Banking/Financial Services                     1368
# Healthcare                                     1276
# Retail and Consumer Services                   1264
# Manufacturing                                  1262
# Government                                      962
# Media & Advertising Services                    893
# Higher Education                                891
# Transportation, or Supply Chain                 859
# Computer Systems Design and Services            843
# Energy                                          578
# Insurance                                       389
# Name: count, dtype: int64
#
# Fréquence des valeurs dans la colonne 'JobSatPoints_1' pour les doublons :
# JobSatPoints_1
# 0.0     11260
# 10.0     4002
# 20.0     2908
# 5.0      1496
# 30.0     1309
#         ...
# 47.0        1
# 83.0        1
# 43.0        1
# 7.5         1
# 36.0        1
# Name: count, Length: 91, dtype: int64
#
# Fréquence des valeurs dans la colonne 'JobSatPoints_4' pour les doublons :
# JobSatPoints_4
# 0.0     19904
# 10.0     2380
# 5.0      1843
# 20.0     1023
# 50.0      473
#         ...
# 52.0        1
# 9.5         1
# 28.0        1
# 68.0        1
# 2.5         1
# Name: count, Length: 72, dtype: int64
#
# Fréquence des valeurs dans la colonne 'JobSatPoints_5' pour les doublons :
# JobSatPoints_5
# 0.0     17801
# 10.0     3098
# 5.0      2321
# 20.0      985
# 50.0      603
#         ...
# 87.0        1
# 9.5         1
# 27.0        1
# 36.0        1
# 84.0        1
# Name: count, Length: 78, dtype: int64
#
# Fréquence des valeurs dans la colonne 'JobSatPoints_6' pour les doublons :
# JobSatPoints_6
# 0.0     7904
# 20.0    4348
# 10.0    3321
# 30.0    2480
# 15.0    1466
#         ...
# 48.0       1
# 44.0       1
# 64.0       1
# 54.0       1
# 63.0       1
# Name: count, Length: 93, dtype: int64
#
# Fréquence des valeurs dans la colonne 'JobSatPoints_7' pour les doublons :
# JobSatPoints_7
# 0.0     8106
# 20.0    4230
# 10.0    3929
# 30.0    2079
# 15.0    1601
#         ...
# 86.0       1
# 38.0       1
# 67.0       1
# 17.5       1
# 36.0       1
# Name: count, Length: 91, dtype: int64
#
# Fréquence des valeurs dans la colonne 'JobSatPoints_8' pour les doublons :
# JobSatPoints_8
# 0.0     10065
# 20.0     3695
# 10.0     3605
# 30.0     1872
# 15.0     1401
#         ...
# 67.5        1
# 59.0        1
# 36.0        1
# 47.0        1
# 86.0        1
# Name: count, Length: 88, dtype: int64
#
# Fréquence des valeurs dans la colonne 'JobSatPoints_9' pour les doublons :
# JobSatPoints_9
# 0.0     12558
# 10.0     3953
# 20.0     2704
# 5.0      1885
# 15.0     1135
#         ...
# 9.5         1
# 87.0        1
# 58.0        1
# 86.0        1
# 53.0        1
# Name: count, Length: 85, dtype: int64
#
# Fréquence des valeurs dans la colonne 'JobSatPoints_10' pour les doublons :
# JobSatPoints_10
# 0.0      17316
# 10.0      3158
# 5.0       2298
# 20.0      1199
# 100.0      579
#          ...
# 43.0         1
# 74.0         1
# 97.0         1
# 28.0         1
# 34.0         1
# Name: count, Length: 75, dtype: int64
#
# Fréquence des valeurs dans la colonne 'JobSatPoints_11' pour les doublons :
# JobSatPoints_11
# 0.0     18275
# 10.0     2951
# 5.0      2056
# 20.0     1032
# 50.0      576
#         ...
# 71.0        1
# 53.0        1
# 59.0        1
# 49.0        1
# 73.0        1
# Name: count, Length: 79, dtype: int64
#
# Fréquence des valeurs dans la colonne 'SurveyLength' pour les doublons :
# SurveyLength
# Appropriate in length    38693
# Too long                 16470
# Too short                  908
# Name: count, dtype: int64
#
# Fréquence des valeurs dans la colonne 'SurveyEase' pour les doublons :
# SurveyEase
# Easy                          30021
# Neither easy nor difficult    24531
# Difficult                      1576
# Name: count, dtype: int64
#
# Fréquence des valeurs dans la colonne 'ConvertedCompYearly' pour les doublons :
# ConvertedCompYearly
# 64444.0     321
# 53703.0     307
# 75184.0     230
# 85925.0     226
# 107406.0    208
#            ...
# 81929.0       1
# 47727.0       1
# 88314.0       1
# 5623.0        1
# 49282.0       1
# Name: count, Length: 6109, dtype: int64
#
# Fréquence des valeurs dans la colonne 'JobSat' pour les doublons :
# JobSat
# 8.0     7504
# 7.0     6374
# 6.0     3748
# 9.0     3623
# 10.0    2246
# 5.0     1952
# 3.0     1165
# 4.0     1131
# 2.0      769
# 0.0      308
# 1.0      275
# Name: count, dtype: int64

# %% [markdown]
# ### Task 3: Visualize Duplicates Distribution
# 1. Create visualizations to show the distribution of duplicates across different categories.
# 2. Use bar charts or pie charts to represent the distribution of duplicates by Country and Employment.

# %%
## Write your code here
# !pip install seaborn
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Identifier les doublons dans les colonnes spécifiques
subset_columns = ["Country", "Employment"]
duplicates_subset = df[df.duplicated(subset=subset_columns, keep=False)]

# Analyser la distribution des doublons par 'Country'
country_duplicates = duplicates_subset['Country'].value_counts()

# Analyser la distribution des doublons par 'Employment'
employment_duplicates = duplicates_subset['Employment'].value_counts()

# Visualisation de la distribution des doublons par 'Country' - Graphique à barres
plt.figure(figsize=(10, 6))
sns.barplot(x=country_duplicates.index, y=country_duplicates.values, palette='Blues_d')
plt.title('Distribution des doublons par pays')
plt.xlabel('Pays')
plt.ylabel('Nombre de doublons')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# Visualisation de la distribution des doublons par 'Employment' - Graphique à barres
plt.figure(figsize=(10, 6))
sns.barplot(x=employment_duplicates.index, y=employment_duplicates.values, palette='Greens_d')
plt.title('Distribution des doublons par statut d\'emploi')
plt.xlabel('Statut d\'emploi')
plt.ylabel('Nombre de doublons')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# Optionnel : Visualiser les doublons sous forme de pie chart (camembert)

# Pie chart pour la distribution par pays
plt.figure(figsize=(8, 8))
country_duplicates.plot.pie(autopct='%1.1f%%', colors=sns.color_palette("Blues_d", len(country_duplicates)))
plt.title('Distribution des doublons par pays')
plt.ylabel('')
plt.show()

# Pie chart pour la distribution par statut d'emploi
plt.figure(figsize=(8, 8))
employment_duplicates.plot.pie(autopct='%1.1f%%', colors=sns.color_palette("Greens_d", len(employment_duplicates)))
plt.title('Distribution des doublons par statut d\'emploi')
plt.ylabel('')
plt.show()
# Out:
# Requirement already satisfied: seaborn in /opt/conda/lib/python3.12/site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /opt/conda/lib/python3.12/site-packages (from seaborn) (2.2.4)
# Requirement already satisfied: pandas>=1.2 in /opt/conda/lib/python3.12/site-packages (from seaborn) (2.2.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /opt/conda/lib/python3.12/site-packages (from seaborn) (3.10.1)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/conda/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.2)
# Requirement already satisfied: pillow>=8 in /opt/conda/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.12/site-packages (from pandas>=1.2->seaborn) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.12/site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# /tmp/ipykernel_299/1952513375.py:19: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=country_duplicates.index, y=country_duplicates.values, palette='Blues_d')
# /tmp/ipykernel_299/1952513375.py:29: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=employment_duplicates.index, y=employment_duplicates.values, palette='Greens_d')
# /tmp/ipykernel_299/1952513375.py:34: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all Axes decorations.
#   plt.tight_layout()

# %% [markdown]
# ### Task 4: Strategic Removal of Duplicates
# 1. Decide which columns are critical for defining uniqueness in the dataset.
# 2. Remove duplicates based on a subset of columns if complete row duplication is not a good criterion.

# %%
## Write your code here
df_no_duplicates = df.drop_duplicates(subset=subset_columns, keep='first')

# Afficher les premières lignes du DataFrame après suppression des doublons
print(df_no_duplicates.head())

# Afficher le nombre de lignes après suppression des doublons
print(f"Nombre de lignes après suppression des doublons : {df_no_duplicates.shape[0]}")

# Optionnel : Vérifier que les doublons ont bien été supprimés
duplicates_check = df_no_duplicates[df_no_duplicates.duplicated(subset=subset_columns, keep=False)]
print(f"Nombre de doublons restants : {duplicates_check.shape[0]}")
# Out:
#    ResponseId                      MainBranch                 Age  \
# 0           1  I am a developer by profession  Under 18 years old
# 1           2  I am a developer by profession     35-44 years old
# 3           4           I am learning to code     18-24 years old
# 4           5  I am a developer by profession     18-24 years old
# 5           6     I code primarily as a hobby  Under 18 years old
#
#             Employment RemoteWork   Check  \
# 0  Employed, full-time     Remote  Apples
# 1  Employed, full-time     Remote  Apples
# 3   Student, full-time        NaN  Apples
# 4   Student, full-time        NaN  Apples
# 5   Student, full-time        NaN  Apples
#
#                                     CodingActivities  \
# 0                                              Hobby
# 1  Hobby;Contribute to open-source projects;Other...
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
#
#                                              EdLevel  \
# 0                          Primary/elementary school
# 1       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 3  Some college/university study without earning ...
# 4  Secondary school (e.g. American high school, G...
# 5                          Primary/elementary school
#
#                                            LearnCode  \
# 0                             Books / Physical media
# 1  Books / Physical media;Colleague;On the job tr...
# 3  Other online resources (e.g., videos, blogs, f...
# 4  Other online resources (e.g., videos, blogs, f...
# 5  School (i.e., University, College, etc);Online...
#
#                                      LearnCodeOnline  ... JobSatPoints_6  \
# 0                                                NaN  ...            NaN
# 1  Technical documentation;Blogs;Books;Written Tu...  ...            0.0
# 3  Stack Overflow;How-to videos;Interactive tutorial  ...            NaN
# 4  Technical documentation;Blogs;Written Tutorial...  ...            NaN
# 5                                                NaN  ...            NaN
#
#   JobSatPoints_7 JobSatPoints_8 JobSatPoints_9 JobSatPoints_10  \
# 0            NaN            NaN            NaN             NaN
# 1            0.0            0.0            0.0             0.0
# 3            NaN            NaN            NaN             NaN
# 4            NaN            NaN            NaN             NaN
# 5            NaN            NaN            NaN             NaN
#
#   JobSatPoints_11           SurveyLength SurveyEase ConvertedCompYearly JobSat
# 0             NaN                    NaN        NaN                 NaN    NaN
# 1             0.0                    NaN        NaN                 NaN    NaN
# 3             NaN               Too long       Easy                 NaN    NaN
# 4             NaN              Too short       Easy                 NaN    NaN
# 5             NaN  Appropriate in length       Easy                 NaN    NaN
#
# [5 rows x 114 columns]
# Nombre de lignes après suppression des doublons : 2665
# Nombre de doublons restants : 0

# %% [markdown]
# ## Verify and Document Duplicate Removal Process

# %% [markdown]
# ### Task 5: Documentation
# 1. Document the process of identifying and removing duplicates.

# %% [markdown]
# Here's a concise documentation in English for **the process of identifying and removing duplicates**:
#
# ---
#
# ### Documentation: Identifying and Removing Duplicates
#
# **Step 1: Identify Duplicate Rows**
# - We used `df.duplicated()` to detect fully duplicated rows.
# - `df.duplicated().sum()` gave us the total count of duplicates.
# - We previewed some duplicates using `df[df.duplicated()].head()`.
#
# **Step 2: Analyze Duplicate Characteristics**
# - We analyzed duplicates based on key columns like `MainBranch`, `Employment`, and `RemoteWork` using:
#   ```python
#   df[df.duplicated(subset=['MainBranch', 'Employment', 'RemoteWork'])].head()
#   ```
# - This helped us understand patterns and identify commonly repeated profiles.
#
# **Step 3: Visualize Distribution**
# - We visualized duplicates by `Country` and `Employment` using bar charts to identify which categories had the most duplication.
#
# **Step 4: Remove Duplicates**
# - Instead of removing fully identical rows, we removed duplicates based on selected columns with:
#   ```python
#   df.drop_duplicates(subset=['MainBranch', 'Employment', 'RemoteWork'], inplace=True)
#   ```
# - This retained more unique data while cleaning redundancy.
#
# **Conclusion:**
# By carefully selecting relevant columns and visualizing duplicates, we effectively cleaned the dataset while preserving important and unique survey responses.

# %% [markdown]
# 2. Explain the reasoning behind selecting specific columns for identifying and removing duplicates.

# %% [markdown]
# To clean the dataset without losing valuable data, we selected key columns that best represent the uniqueness of each survey respondent.
#
# Country: Differentiates users geographically. Two users from different countries are unlikely to be the same.
#
# Employment: Indicates job type (e.g., full-time, part-time), which can affect responses.
#
# Age: Helps distinguish between respondents of different age groups.
#
# These columns were chosen because they reflect essential aspects of a participant's identity. Removing duplicates based on all columns might delete valid entries. On the other hand, focusing on these meaningful columns helps eliminate only true duplicates, ensuring cleaner and more accurate data for analysis.

# %% [markdown]
# ### Summary and Next Steps
# **In this lab, you focused on identifying and analyzing duplicate rows within the dataset.**
#
# - You employed various techniques to explore the nature of duplicates and applied strategic methods for their removal.
# - For additional analysis, consider investigating the impact of duplicates on specific analyses and how their removal affects the results.
# - This version of the lab is more focused on duplicate analysis and handling, providing a structured approach to deal with duplicates in a dataset effectively.

# %% [markdown]
# <!--
# ## Change Log
# |Date (YYYY-MM-DD)|Version|Changed By|Change Description|
# |-|-|-|-|
# |2024-11- 05|1.3|Madhusudhan Moole|Updated lab|
# |2024-10-28|1.2|Madhusudhan Moole|Updated lab|
# |2024-09-24|1.1|Madhusudhan Moole|Updated lab|
# |2024-09-23|1.0|Raghul Ramesh|Created lab|
# --!>

# %% [markdown]
# Copyright © IBM Corporation. All rights reserved.
